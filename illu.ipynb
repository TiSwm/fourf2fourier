# %%
# %matplotlib inline
from rayoptics.environment import *
opm, info = open_model(Path.cwd() / "ACL2520U-A-Zemax(ZMX).zmx", info=True)
# opm, info = open_model(Path.cwd() / "AC254-050-A-Zemax(ZMX).zmx", info=True)
# opm.rebuild_from_seq()

sm = opm['seq_model']
osp = opm['optical_spec']
pm = opm['parax_model']
em = opm['ele_model']
pt = opm['part_tree']
ar = opm['analysis_results']

# %%
# osp['fov'] = FieldSpec(osp, key=['object', 'height'], value=0.2, flds=[0., 0.5, 1.], is_relative=True)
# osp['pupil'] = PupilSpec(osp, key=['object', 'NA'], value=0.4)

# sm.set_cur_surface(3)
# sm.set_stop()

# sm.list_elements()
# print("")
# sm.set_cur_surface(3)

# sm.add_surface([0, 1])
# sm.add_surface([0, 50])
# sm.add_surface([+.5, 1, 'N-BAF10', 'Schott'])
# sm.add_surface([-.5, 10])
# sm.add_surface([0, 50])
# sm.add_surface([+.5, 1, 'N-BAF10', 'Schott'])
# sm.add_surface([-.5, 10])
# # sm.add_surface([0, 50])
# # sm.add_surface([+0.3, 1, 'N-BAF10', 'Schott'])
# # sm.add_surface([-0.3, 10])

# # sm.list_surfaces()
# sm.list_elements()
# print(sm.cur_surface)
# print(sm.get_num_surfaces())
# sm.list_surfaces()

# # sm.set_cur_surface(3)
# # # sm.set_stop()
# opm.rebuild_from_seq()



# sm.list_model()

# %%
layout_plt = plt.figure(FigureClass=InteractiveLayout, opt_model=opm, dpi=2000).plot()
# Out:
# <InteractiveLayout size 12800x9600 with 1 Axes>
